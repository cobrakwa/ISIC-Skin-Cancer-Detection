# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, ConcatDataset
from sklearn.model_selection import train_test_split
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchvision.models import resnet18
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc
import numpy as np
import os
import re

# %%
if not os.path.exists("saved_models"):
    os.makedirs("saved_models")

# %% [markdown]
# ## Function Definition

# %%
from sklearn.metrics import roc_auc_score

def custom_metric(y_true, y_pred, min_tpr=0.8):
    """
    Calculate the partial AUC (pAUC) based on a minimum TPR threshold.

    Args:
    y_true (array): True binary labels.
    y_pred (array): Predicted probabilities.
    min_tpr (float): Minimum TPR threshold (default: 0.8).

    Returns:
    float: Scaled pAUC value.
    """
    max_fpr = 1 - min_tpr  
    v_gt = abs(y_true - 1)  
    v_pred = np.array([1.0 - x for x in y_pred])  

    
    pauc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    pauc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (pauc_scaled - 0.5)

    return pauc

# %% [markdown]
# ## Model Definition

# %%
def load_pretrained_resnet18(num_classes):
    """
    Load the ResNet-18 model, downloading pretrained weights if necessary.
    """
    model_path = "saved_models/resnet18.pth"
    
    if os.path.exists(model_path):
        print(f"Loading pretrained ResNet-18 model from {model_path}.")
        model = resnet18()
        model.load_state_dict(torch.load(model_path))
    else:
        print(f"Downloading and saving ResNet-18 pretrained weights to {model_path}.")
        model = resnet18(pretrained=True)
        torch.save(model.state_dict(), model_path)

    
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model

# %% [markdown]
# ## Hyperparams

# %%
batch_size = 32
learning_rate = 0.000001
num_epochs = 50
num_classes = 2
dropout_rate = 0.4

# %% [markdown]
# ## Dataset Processing

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

augment_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop((128, 128), scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

dataset = datasets.ImageFolder(root='../data/balanced_data', transform=transform)
num_classes = len(dataset.classes)


train_indices, temp_indices, train_labels, temp_labels = train_test_split(
    np.arange(len(dataset)),
    [label for _, label in dataset.samples],
    test_size=0.2,
    stratify=[label for _, label in dataset.samples],
    random_state=42
)

val_indices, test_indices, _, _ = train_test_split(
    temp_indices,
    temp_labels,
    test_size=0.5,
    stratify=temp_labels,
    random_state=42
)


train_dataset = Subset(dataset, train_indices)
train_augmented_dataset = datasets.ImageFolder(root='../data/balanced_data', transform=augment_transform)
train_augmented_indices = np.random.choice(train_indices, size=len(train_indices), replace=False)
train_augmented_dataset = Subset(train_augmented_dataset, train_augmented_indices)
train_combined_dataset = ConcatDataset([train_dataset, train_augmented_dataset])

val_dataset = Subset(dataset, val_indices)
val_augmented_dataset = datasets.ImageFolder(root='../data/balanced_data', transform=augment_transform)
val_augmented_indices = np.random.choice(val_indices, size=len(val_indices), replace=False)
val_augmented_dataset = Subset(val_augmented_dataset, val_augmented_indices)
val_combined_dataset = ConcatDataset([val_dataset, val_augmented_dataset])

test_dataset = Subset(dataset, test_indices)

train_loader = DataLoader(train_combined_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_combined_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Init Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = load_pretrained_resnet18(num_classes=num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# Loading pretrained ResNet-18 model from saved_models/resnet18.pth.

# %% [markdown]
# ## Training

# %%
best_val_loss = float('inf')
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

        
        preds = torch.argmax(outputs, dim=1)
        correct_train += (preds == labels).sum().item()
        total_train += labels.size(0)

    avg_train_loss = running_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    train_accuracies.append(correct_train / total_train)

    
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

            
            preds = torch.argmax(outputs, dim=1)
            correct_val += (preds == labels).sum().item()
            total_val += labels.size(0)

    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    val_accuracies.append(correct_val / total_val)

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}, "
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracies[-1]:.4f}")

    
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        model_path = "saved_models/best_model.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Best model saved to {model_path}.")
# Out:
# Epoch [1/50], Train Loss: 0.7621, Train Accuracy: 0.5143, Validation Loss: 0.7549, Validation Accuracy: 0.4873
# Best model saved to saved_models/best_model.pth.
# Epoch [2/50], Train Loss: 0.7336, Train Accuracy: 0.5398, Validation Loss: 0.7073, Validation Accuracy: 0.5696
# Best model saved to saved_models/best_model.pth.
# Epoch [3/50], Train Loss: 0.6876, Train Accuracy: 0.5812, Validation Loss: 0.7101, Validation Accuracy: 0.5949
# Epoch [4/50], Train Loss: 0.6661, Train Accuracy: 0.6099, Validation Loss: 0.6877, Validation Accuracy: 0.6203
# Best model saved to saved_models/best_model.pth.
# Epoch [5/50], Train Loss: 0.6482, Train Accuracy: 0.6258, Validation Loss: 0.6358, Validation Accuracy: 0.6835
# Best model saved to saved_models/best_model.pth.
# Epoch [6/50], Train Loss: 0.6220, Train Accuracy: 0.6521, Validation Loss: 0.6141, Validation Accuracy: 0.6899
# Best model saved to saved_models/best_model.pth.
# Epoch [7/50], Train Loss: 0.6081, Train Accuracy: 0.6616, Validation Loss: 0.6213, Validation Accuracy: 0.6646
# Epoch [8/50], Train Loss: 0.5830, Train Accuracy: 0.6998, Validation Loss: 0.5792, Validation Accuracy: 0.7278
# Best model saved to saved_models/best_model.pth.
# Epoch [9/50], Train Loss: 0.5824, Train Accuracy: 0.6998, Validation Loss: 0.5889, Validation Accuracy: 0.6899
# Epoch [10/50], Train Loss: 0.5583, Train Accuracy: 0.7325, Validation Loss: 0.5735, Validation Accuracy: 0.7152
# Best model saved to saved_models/best_model.pth.
# Epoch [11/50], Train Loss: 0.5342, Train Accuracy: 0.7500, Validation Loss: 0.5623, Validation Accuracy: 0.6899
# Best model saved to saved_models/best_model.pth.
# Epoch [12/50], Train Loss: 0.5459, Train Accuracy: 0.7396, Validation Loss: 0.5527, Validation Accuracy: 0.7089
# Best model saved to saved_models/best_model.pth.
# Epoch [13/50], Train Loss: 0.5113, Train Accuracy: 0.7683, Validation Loss: 0.5233, Validation Accuracy: 0.7468
# Best model saved to saved_models/best_model.pth.
# Epoch [14/50], Train Loss: 0.4925, Train Accuracy: 0.7795, Validation Loss: 0.5637, Validation Accuracy: 0.7468
# Epoch [15/50], Train Loss: 0.4891, Train Accuracy: 0.7850, Validation Loss: 0.5295, Validation Accuracy: 0.7468
# Epoch [16/50], Train Loss: 0.4756, Train Accuracy: 0.7866, Validation Loss: 0.5113, Validation Accuracy: 0.7405
# Best model saved to saved_models/best_model.pth.
# Epoch [17/50], Train Loss: 0.4615, Train Accuracy: 0.8025, Validation Loss: 0.5120, Validation Accuracy: 0.8038
# Epoch [18/50], Train Loss: 0.4694, Train Accuracy: 0.7858, Validation Loss: 0.5122, Validation Accuracy: 0.7658
# Epoch [19/50], Train Loss: 0.4579, Train Accuracy: 0.8025, Validation Loss: 0.5027, Validation Accuracy: 0.7595
# Best model saved to saved_models/best_model.pth.
# Epoch [20/50], Train Loss: 0.4458, Train Accuracy: 0.8232, Validation Loss: 0.4901, Validation Accuracy: 0.7532
# Best model saved to saved_models/best_model.pth.
# Epoch [21/50], Train Loss: 0.4305, Train Accuracy: 0.8185, Validation Loss: 0.5276, Validation Accuracy: 0.7342
# Epoch [22/50], Train Loss: 0.4209, Train Accuracy: 0.8336, Validation Loss: 0.5035, Validation Accuracy: 0.7658
# Epoch [23/50], Train Loss: 0.4168, Train Accuracy: 0.8248, Validation Loss: 0.4783, Validation Accuracy: 0.7658
# Best model saved to saved_models/best_model.pth.
# Epoch [24/50], Train Loss: 0.4054, Train Accuracy: 0.8288, Validation Loss: 0.4649, Validation Accuracy: 0.7848
# Best model saved to saved_models/best_model.pth.
# Epoch [25/50], Train Loss: 0.4065, Train Accuracy: 0.8272, Validation Loss: 0.4832, Validation Accuracy: 0.7595
# Epoch [26/50], Train Loss: 0.3955, Train Accuracy: 0.8479, Validation Loss: 0.4788, Validation Accuracy: 0.7405
# Epoch [27/50], Train Loss: 0.3869, Train Accuracy: 0.8408, Validation Loss: 0.4834, Validation Accuracy: 0.7532
# Epoch [28/50], Train Loss: 0.3983, Train Accuracy: 0.8400, Validation Loss: 0.4789, Validation Accuracy: 0.7722
# Epoch [29/50], Train Loss: 0.3724, Train Accuracy: 0.8479, Validation Loss: 0.4987, Validation Accuracy: 0.7595
# Epoch [30/50], Train Loss: 0.3752, Train Accuracy: 0.8463, Validation Loss: 0.4636, Validation Accuracy: 0.7975
# Best model saved to saved_models/best_model.pth.
# Epoch [31/50], Train Loss: 0.3617, Train Accuracy: 0.8575, Validation Loss: 0.4506, Validation Accuracy: 0.8228
# Best model saved to saved_models/best_model.pth.
# Epoch [32/50], Train Loss: 0.3616, Train Accuracy: 0.8471, Validation Loss: 0.4772, Validation Accuracy: 0.7595
# Epoch [33/50], Train Loss: 0.3568, Train Accuracy: 0.8710, Validation Loss: 0.4923, Validation Accuracy: 0.7722
# Epoch [34/50], Train Loss: 0.3441, Train Accuracy: 0.8646, Validation Loss: 0.5022, Validation Accuracy: 0.7722
# Epoch [35/50], Train Loss: 0.3506, Train Accuracy: 0.8599, Validation Loss: 0.4465, Validation Accuracy: 0.8038
# Best model saved to saved_models/best_model.pth.
# Epoch [36/50], Train Loss: 0.3420, Train Accuracy: 0.8662, Validation Loss: 0.4811, Validation Accuracy: 0.8038
# Epoch [37/50], Train Loss: 0.3382, Train Accuracy: 0.8543, Validation Loss: 0.4419, Validation Accuracy: 0.7975
# Best model saved to saved_models/best_model.pth.
# Epoch [38/50], Train Loss: 0.3304, Train Accuracy: 0.8766, Validation Loss: 0.4763, Validation Accuracy: 0.7911
# Epoch [39/50], Train Loss: 0.3333, Train Accuracy: 0.8639, Validation Loss: 0.4639, Validation Accuracy: 0.7975
# Epoch [40/50], Train Loss: 0.3114, Train Accuracy: 0.8830, Validation Loss: 0.4838, Validation Accuracy: 0.7722
# Epoch [41/50], Train Loss: 0.3124, Train Accuracy: 0.8774, Validation Loss: 0.4897, Validation Accuracy: 0.7975
# Epoch [42/50], Train Loss: 0.2974, Train Accuracy: 0.8822, Validation Loss: 0.4598, Validation Accuracy: 0.8165
# Epoch [43/50], Train Loss: 0.3162, Train Accuracy: 0.8782, Validation Loss: 0.4339, Validation Accuracy: 0.7975
# Best model saved to saved_models/best_model.pth.
# Epoch [44/50], Train Loss: 0.3115, Train Accuracy: 0.8782, Validation Loss: 0.4395, Validation Accuracy: 0.8101
# Epoch [45/50], Train Loss: 0.2809, Train Accuracy: 0.8957, Validation Loss: 0.4541, Validation Accuracy: 0.7975
# Epoch [46/50], Train Loss: 0.2949, Train Accuracy: 0.8861, Validation Loss: 0.4553, Validation Accuracy: 0.7468
# Epoch [47/50], Train Loss: 0.2949, Train Accuracy: 0.8901, Validation Loss: 0.4465, Validation Accuracy: 0.7975
# Epoch [48/50], Train Loss: 0.2959, Train Accuracy: 0.8925, Validation Loss: 0.4772, Validation Accuracy: 0.8038
# Epoch [49/50], Train Loss: 0.2905, Train Accuracy: 0.8925, Validation Loss: 0.4522, Validation Accuracy: 0.7848
# Epoch [50/50], Train Loss: 0.2723, Train Accuracy: 0.8957, Validation Loss: 0.4603, Validation Accuracy: 0.7658

# %% [markdown]
# ## Eval

# %%
best_model_path = "saved_models/best_model.pth"
if not os.path.exists(best_model_path):
    raise FileNotFoundError(f"No model file found at {best_model_path}.")

print(f"Loading the best model: {best_model_path}")
model.load_state_dict(torch.load(best_model_path))
model.eval()

running_test_loss = 0.0
correct_test = 0
total_test = 0
all_labels = []
all_preds = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_test_loss += loss.item()

        probs = torch.softmax(outputs, dim=1)[:, 1]  
        preds = torch.argmax(outputs, dim=1)

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

        correct_test += (preds == labels).sum().item()
        total_test += labels.size(0)

avg_test_loss = running_test_loss / len(test_loader)
test_accuracy = correct_test / total_test
print(f"Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")


print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=dataset.classes))


pAUC = custom_metric(np.array(all_labels), np.array(all_probs), min_tpr=0.8)
print(f"Partial AUC (pAUC) above TPR=0.8 (normalized to [0, 0.2]): {pAUC:.4f}")
# Out:
# Loading the best model: saved_models/best_model.pth
# Test Loss: 0.4091, Test Accuracy: 0.8101
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        40
#            1       0.88      0.72      0.79        39
#
#     accuracy                           0.81        79
#    macro avg       0.82      0.81      0.81        79
# weighted avg       0.82      0.81      0.81        79
#
# Partial AUC (pAUC) above TPR=0.8 (normalized to [0, 0.2]): 0.1076

# %% [markdown]
# ## Plotting

# %%
fpr, tpr, _ = roc_curve(all_labels, all_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="ROC Curve")
plt.axhline(y=0.8, color='gray', linestyle='--', label="TPR Threshold = 0.8")
plt.fill_between(fpr, tpr, where=(tpr >= 0.8), color='green', alpha=0.3, label=f"pAUC = {pAUC:.4f}")
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve with pAUC Highlighted')
plt.legend()
roc_plot_path = os.path.join("saved_models", "roc_curve_with_pauc.png")
plt.savefig(roc_plot_path)
plt.show()
print(f"ROC Curve plot saved to {roc_plot_path}")


plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.scatter(len(train_losses), avg_test_loss, label=f'Test Loss: {avg_test_loss:.4f}', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss with Test Loss')
plt.legend()
loss_plot_path = os.path.join("saved_models", "training_vs_validation_loss.png")
plt.savefig(loss_plot_path)
plt.show()
print(f"Loss plot saved to {loss_plot_path}")


plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Validation Accuracy')
plt.scatter(len(train_accuracies), test_accuracy, label=f'Test Accuracy: {test_accuracy:.4f}', color='red')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy with Test Accuracy')
plt.legend(loc='lower right', fontsize='small')
accuracy_plot_path = os.path.join("saved_models", "training_vs_validation_accuracy.png")
plt.savefig(accuracy_plot_path)
plt.show()
print(f"Accuracy plot saved to {accuracy_plot_path}")
# Out:
# ROC Curve plot saved to saved_models/roc_curve_with_pauc.png
# Loss plot saved to saved_models/training_vs_validation_loss.png
# Accuracy plot saved to saved_models/training_vs_validation_accuracy.png

# %% [markdown]
# ## Save Model Params

# %%
params_file_path = os.path.join("saved_models", "model_params.txt")
with open(params_file_path, "w") as f:
    f.write("Model Architecture:\n")
    f.write(str(model) + "\n\n")
    f.write("Hyperparameters:\n")
    f.write(f"Batch Size: {batch_size}\n")
    f.write(f"Learning Rate: {learning_rate}\n")
    f.write(f"Number of Epochs: {num_epochs}\n")
    f.write(f"Number of Classes: {num_classes}\n")
    f.write(f"Dropout Rate: {dropout_rate}\n")
    f.write(f"Optimizer: Adam\n")
    f.write(f"Loss Function: CrossEntropyLoss\n")
print(f"Model parameters and architecture saved to {params_file_path}")
# Out:
# Model parameters and architecture saved to saved_models/model_params.txt
