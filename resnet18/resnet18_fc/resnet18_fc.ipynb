# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Subset, ConcatDataset
from sklearn.model_selection import train_test_split
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchvision.models import resnet18
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc
import numpy as np
import os
import re

# %%
if not os.path.exists("saved_models"):
    os.makedirs("saved_models")

# %% [markdown]
# ## Function Definition

# %%
from sklearn.metrics import roc_auc_score

def custom_metric(y_true, y_pred, min_tpr=0.8):
    """
    Calculate the partial AUC (pAUC) based on a minimum TPR threshold.

    Args:
    y_true (array): True binary labels.
    y_pred (array): Predicted probabilities.
    min_tpr (float): Minimum TPR threshold (default: 0.8).

    Returns:
    float: Scaled pAUC value.
    """
    max_fpr = 1 - min_tpr  
    v_gt = abs(y_true - 1)  
    v_pred = np.array([1.0 - x for x in y_pred])  

    
    pauc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    pauc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (pauc_scaled - 0.5)

    return pauc

# %% [markdown]
# ## Model Definition

# %%
def load_resnet18_train_fc(num_classes):
    """
    Load ResNet-18, freezing all layers except the final fully connected layer.

    Args:
    - num_classes (int): Number of output classes.

    Returns:
    - model (torch.nn.Module): Modified ResNet-18 model with only the `fc` layer trainable.
    """
    
    model = resnet18(pretrained=True)

    
    for param in model.parameters():
        param.requires_grad = False

    
    model.fc = nn.Linear(model.fc.in_features, num_classes)

    
    for param in model.fc.parameters():
        param.requires_grad = True

    return model

# %% [markdown]
# ## Hyperparams

# %%
batch_size = 32
learning_rate = 0.0001 
num_epochs = 50
num_classes = 2
dropout_rate = 0.4

# %% [markdown]
# ## Dataset Processing

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

augment_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop((128, 128), scale=(0.8, 1.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
])

dataset = datasets.ImageFolder(root='../data/balanced_data', transform=transform)
num_classes = len(dataset.classes)


train_indices, temp_indices, train_labels, temp_labels = train_test_split(
    np.arange(len(dataset)),
    [label for _, label in dataset.samples],
    test_size=0.2,
    stratify=[label for _, label in dataset.samples],
    random_state=42
)

val_indices, test_indices, _, _ = train_test_split(
    temp_indices,
    temp_labels,
    test_size=0.5,
    stratify=temp_labels,
    random_state=42
)


train_dataset = Subset(dataset, train_indices)
train_augmented_dataset = datasets.ImageFolder(root='../data/balanced_data', transform=augment_transform)
train_augmented_indices = np.random.choice(train_indices, size=len(train_indices), replace=False)
train_augmented_dataset = Subset(train_augmented_dataset, train_augmented_indices)
train_combined_dataset = ConcatDataset([train_dataset, train_augmented_dataset])

val_dataset = Subset(dataset, val_indices)
val_augmented_dataset = datasets.ImageFolder(root='../data/balanced_data', transform=augment_transform)
val_augmented_indices = np.random.choice(val_indices, size=len(val_indices), replace=False)
val_augmented_dataset = Subset(val_augmented_dataset, val_augmented_indices)
val_combined_dataset = ConcatDataset([val_dataset, val_augmented_dataset])

test_dataset = Subset(dataset, test_indices)

train_loader = DataLoader(train_combined_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_combined_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %% [markdown]
# ## Init Model

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = load_resnet18_train_fc(num_classes=num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# /home/jone/anaconda3/envs/SUTD/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/jone/anaconda3/envs/SUTD/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Training

# %%
best_val_loss = float('inf')
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    correct_train = 0
    total_train = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

        
        preds = torch.argmax(outputs, dim=1)
        correct_train += (preds == labels).sum().item()
        total_train += labels.size(0)

    avg_train_loss = running_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    train_accuracies.append(correct_train / total_train)

    
    model.eval()
    running_val_loss = 0.0
    correct_val = 0
    total_val = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()

            
            preds = torch.argmax(outputs, dim=1)
            correct_val += (preds == labels).sum().item()
            total_val += labels.size(0)

    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    val_accuracies.append(correct_val / total_val)

    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}, "
          f"Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracies[-1]:.4f}")

    
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        model_path = "saved_models/best_model.pth"
        torch.save(model.state_dict(), model_path)
        print(f"Best model saved to {model_path}.")
# Out:
# Epoch [1/50], Train Loss: 0.7354, Train Accuracy: 0.5414, Validation Loss: 0.7161, Validation Accuracy: 0.5759
# Best model saved to saved_models/best_model.pth.
# Epoch [2/50], Train Loss: 0.6720, Train Accuracy: 0.5971, Validation Loss: 0.6562, Validation Accuracy: 0.6646
# Best model saved to saved_models/best_model.pth.
# Epoch [3/50], Train Loss: 0.6504, Train Accuracy: 0.6290, Validation Loss: 0.6360, Validation Accuracy: 0.6519
# Best model saved to saved_models/best_model.pth.
# Epoch [4/50], Train Loss: 0.6084, Train Accuracy: 0.6576, Validation Loss: 0.5968, Validation Accuracy: 0.7025
# Best model saved to saved_models/best_model.pth.
# Epoch [5/50], Train Loss: 0.5907, Train Accuracy: 0.6895, Validation Loss: 0.6190, Validation Accuracy: 0.7089
# Epoch [6/50], Train Loss: 0.5750, Train Accuracy: 0.6951, Validation Loss: 0.5783, Validation Accuracy: 0.7215
# Best model saved to saved_models/best_model.pth.
# Epoch [7/50], Train Loss: 0.5701, Train Accuracy: 0.7046, Validation Loss: 0.5572, Validation Accuracy: 0.7532
# Best model saved to saved_models/best_model.pth.
# Epoch [8/50], Train Loss: 0.5537, Train Accuracy: 0.7158, Validation Loss: 0.5907, Validation Accuracy: 0.7278
# Epoch [9/50], Train Loss: 0.5280, Train Accuracy: 0.7389, Validation Loss: 0.5641, Validation Accuracy: 0.7532
# Epoch [10/50], Train Loss: 0.5338, Train Accuracy: 0.7436, Validation Loss: 0.5464, Validation Accuracy: 0.7468
# Best model saved to saved_models/best_model.pth.
# Epoch [11/50], Train Loss: 0.5155, Train Accuracy: 0.7540, Validation Loss: 0.5401, Validation Accuracy: 0.7722
# Best model saved to saved_models/best_model.pth.
# Epoch [12/50], Train Loss: 0.5125, Train Accuracy: 0.7572, Validation Loss: 0.5547, Validation Accuracy: 0.7722
# Epoch [13/50], Train Loss: 0.5111, Train Accuracy: 0.7420, Validation Loss: 0.5429, Validation Accuracy: 0.7468
# Epoch [14/50], Train Loss: 0.4945, Train Accuracy: 0.7564, Validation Loss: 0.5120, Validation Accuracy: 0.7975
# Best model saved to saved_models/best_model.pth.
# Epoch [15/50], Train Loss: 0.4911, Train Accuracy: 0.7667, Validation Loss: 0.5245, Validation Accuracy: 0.7722
# Epoch [16/50], Train Loss: 0.4860, Train Accuracy: 0.7834, Validation Loss: 0.5684, Validation Accuracy: 0.7468
# Epoch [17/50], Train Loss: 0.4806, Train Accuracy: 0.7818, Validation Loss: 0.5645, Validation Accuracy: 0.7532
# Epoch [18/50], Train Loss: 0.4843, Train Accuracy: 0.7739, Validation Loss: 0.5126, Validation Accuracy: 0.7975
# Epoch [19/50], Train Loss: 0.4671, Train Accuracy: 0.7723, Validation Loss: 0.5481, Validation Accuracy: 0.7911
# Epoch [20/50], Train Loss: 0.4685, Train Accuracy: 0.7795, Validation Loss: 0.5287, Validation Accuracy: 0.8038
# Epoch [21/50], Train Loss: 0.4653, Train Accuracy: 0.7858, Validation Loss: 0.5125, Validation Accuracy: 0.7911
# Epoch [22/50], Train Loss: 0.4584, Train Accuracy: 0.7994, Validation Loss: 0.5235, Validation Accuracy: 0.7975
# Epoch [23/50], Train Loss: 0.4671, Train Accuracy: 0.7826, Validation Loss: 0.5142, Validation Accuracy: 0.7975
# Epoch [24/50], Train Loss: 0.4665, Train Accuracy: 0.7898, Validation Loss: 0.5556, Validation Accuracy: 0.8038
# Epoch [25/50], Train Loss: 0.4656, Train Accuracy: 0.7707, Validation Loss: 0.5138, Validation Accuracy: 0.7911
# Epoch [26/50], Train Loss: 0.4621, Train Accuracy: 0.7842, Validation Loss: 0.5155, Validation Accuracy: 0.8165
# Epoch [27/50], Train Loss: 0.4492, Train Accuracy: 0.8049, Validation Loss: 0.5458, Validation Accuracy: 0.7722
# Epoch [28/50], Train Loss: 0.4638, Train Accuracy: 0.7755, Validation Loss: 0.5299, Validation Accuracy: 0.7911
# Epoch [29/50], Train Loss: 0.4389, Train Accuracy: 0.7946, Validation Loss: 0.5153, Validation Accuracy: 0.7848
# Epoch [30/50], Train Loss: 0.4332, Train Accuracy: 0.7938, Validation Loss: 0.5323, Validation Accuracy: 0.7722
# Epoch [31/50], Train Loss: 0.4587, Train Accuracy: 0.7874, Validation Loss: 0.5967, Validation Accuracy: 0.7658
# Epoch [32/50], Train Loss: 0.4527, Train Accuracy: 0.7954, Validation Loss: 0.5020, Validation Accuracy: 0.8101
# Best model saved to saved_models/best_model.pth.
# Epoch [33/50], Train Loss: 0.4825, Train Accuracy: 0.7723, Validation Loss: 0.5318, Validation Accuracy: 0.8038
# Epoch [34/50], Train Loss: 0.4497, Train Accuracy: 0.7866, Validation Loss: 0.5176, Validation Accuracy: 0.7722
# Epoch [35/50], Train Loss: 0.4268, Train Accuracy: 0.8002, Validation Loss: 0.5451, Validation Accuracy: 0.8101
# Epoch [36/50], Train Loss: 0.4416, Train Accuracy: 0.7946, Validation Loss: 0.5016, Validation Accuracy: 0.7975
# Best model saved to saved_models/best_model.pth.
# Epoch [37/50], Train Loss: 0.4431, Train Accuracy: 0.8153, Validation Loss: 0.5592, Validation Accuracy: 0.8101
# Epoch [38/50], Train Loss: 0.4559, Train Accuracy: 0.7938, Validation Loss: 0.5096, Validation Accuracy: 0.7911
# Epoch [39/50], Train Loss: 0.4276, Train Accuracy: 0.8129, Validation Loss: 0.4905, Validation Accuracy: 0.8228
# Best model saved to saved_models/best_model.pth.
# Epoch [40/50], Train Loss: 0.4266, Train Accuracy: 0.7914, Validation Loss: 0.5354, Validation Accuracy: 0.7722
# Epoch [41/50], Train Loss: 0.4466, Train Accuracy: 0.8002, Validation Loss: 0.5582, Validation Accuracy: 0.7722
# Epoch [42/50], Train Loss: 0.4525, Train Accuracy: 0.8025, Validation Loss: 0.4990, Validation Accuracy: 0.7785
# Epoch [43/50], Train Loss: 0.4395, Train Accuracy: 0.8049, Validation Loss: 0.5247, Validation Accuracy: 0.8101
# Epoch [44/50], Train Loss: 0.4171, Train Accuracy: 0.8201, Validation Loss: 0.5301, Validation Accuracy: 0.7658
# Epoch [45/50], Train Loss: 0.4311, Train Accuracy: 0.8113, Validation Loss: 0.5541, Validation Accuracy: 0.7975
# Epoch [46/50], Train Loss: 0.4359, Train Accuracy: 0.8018, Validation Loss: 0.5768, Validation Accuracy: 0.7911
# Epoch [47/50], Train Loss: 0.4480, Train Accuracy: 0.7962, Validation Loss: 0.5469, Validation Accuracy: 0.7975
# Epoch [48/50], Train Loss: 0.4289, Train Accuracy: 0.8081, Validation Loss: 0.5554, Validation Accuracy: 0.7722
# Epoch [49/50], Train Loss: 0.4271, Train Accuracy: 0.8145, Validation Loss: 0.5344, Validation Accuracy: 0.7722
# Epoch [50/50], Train Loss: 0.4288, Train Accuracy: 0.7978, Validation Loss: 0.5753, Validation Accuracy: 0.7722

# %% [markdown]
# ## Eval

# %%
best_model_path = "saved_models/best_model.pth"
if not os.path.exists(best_model_path):
    raise FileNotFoundError(f"No model file found at {best_model_path}.")

print(f"Loading the best model: {best_model_path}")
model.load_state_dict(torch.load(best_model_path))
model.eval()

running_test_loss = 0.0
correct_test = 0
total_test = 0
all_labels = []
all_preds = []
all_probs = []

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_test_loss += loss.item()

        probs = torch.softmax(outputs, dim=1)[:, 1]  
        preds = torch.argmax(outputs, dim=1)

        all_labels.extend(labels.cpu().numpy())
        all_preds.extend(preds.cpu().numpy())
        all_probs.extend(probs.cpu().numpy())

        correct_test += (preds == labels).sum().item()
        total_test += labels.size(0)

avg_test_loss = running_test_loss / len(test_loader)
test_accuracy = correct_test / total_test
print(f"Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")


print("Classification Report:")
print(classification_report(all_labels, all_preds, target_names=dataset.classes))


pAUC = custom_metric(np.array(all_labels), np.array(all_probs), min_tpr=0.8)
print(f"Partial AUC (pAUC) above TPR=0.8 (normalized to [0, 0.2]): {pAUC:.4f}")
# Out:
# Loading the best model: saved_models/best_model.pth
# Test Loss: 0.4053, Test Accuracy: 0.8228
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83        40
#            1       0.84      0.79      0.82        39
#
#     accuracy                           0.82        79
#    macro avg       0.82      0.82      0.82        79
# weighted avg       0.82      0.82      0.82        79
#
# Partial AUC (pAUC) above TPR=0.8 (normalized to [0, 0.2]): 0.1171

# %% [markdown]
# ## Plotting

# %%
fpr, tpr, _ = roc_curve(all_labels, all_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label="ROC Curve")
plt.axhline(y=0.8, color='gray', linestyle='--', label="TPR Threshold = 0.8")
plt.fill_between(fpr, tpr, where=(tpr >= 0.8), color='green', alpha=0.3, label=f"pAUC = {pAUC:.4f}")
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('ROC Curve with pAUC Highlighted')
plt.legend()
roc_plot_path = os.path.join("saved_models", "roc_curve_with_pauc.png")
plt.savefig(roc_plot_path)
plt.show()
print(f"ROC Curve plot saved to {roc_plot_path}")


plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.scatter(len(train_losses), avg_test_loss, label=f'Test Loss: {avg_test_loss:.4f}', color='red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss with Test Loss')
plt.legend()
loss_plot_path = os.path.join("saved_models", "training_vs_validation_loss.png")
plt.savefig(loss_plot_path)
plt.show()
print(f"Loss plot saved to {loss_plot_path}")


plt.figure(figsize=(8, 6))
plt.plot(range(1, len(train_accuracies) + 1), train_accuracies, label='Training Accuracy')
plt.plot(range(1, len(val_accuracies) + 1), val_accuracies, label='Validation Accuracy')
plt.scatter(len(train_accuracies), test_accuracy, label=f'Test Accuracy: {test_accuracy:.4f}', color='red')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy with Test Accuracy')
plt.legend(loc='lower right', fontsize='small')
accuracy_plot_path = os.path.join("saved_models", "training_vs_validation_accuracy.png")
plt.savefig(accuracy_plot_path)
plt.show()
print(f"Accuracy plot saved to {accuracy_plot_path}")
# Out:
# ROC Curve plot saved to saved_models/roc_curve_with_pauc.png
# Loss plot saved to saved_models/training_vs_validation_loss.png
# Accuracy plot saved to saved_models/training_vs_validation_accuracy.png

# %% [markdown]
# ## Save Model Params

# %%
params_file_path = os.path.join("saved_models", "model_params.txt")
with open(params_file_path, "w") as f:
    f.write("Model Architecture:\n")
    f.write(str(model) + "\n\n")
    f.write("Hyperparameters:\n")
    f.write(f"Batch Size: {batch_size}\n")
    f.write(f"Learning Rate: {learning_rate}\n")
    f.write(f"Number of Epochs: {num_epochs}\n")
    f.write(f"Number of Classes: {num_classes}\n")
    f.write(f"Dropout Rate: {dropout_rate}\n")
    f.write(f"Optimizer: Adam\n")
    f.write(f"Loss Function: CrossEntropyLoss\n")
print(f"Model parameters and architecture saved to {params_file_path}")
# Out:
# Model parameters and architecture saved to saved_models/model_params.txt
