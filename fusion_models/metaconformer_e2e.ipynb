# %% [markdown]
# ## Imports

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_auc_score, roc_curve

# %% [markdown]
# ## Config

# %%
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
metadata_path = '../data/balanced_data/normalized_metadata.csv'
normalization_params_path = '../data/balanced_data/normalization_params.json'
image_dir = '../data/balanced_data'
pretrained_conformer_path = './pretrained/conformer.pth'
pretrained_dnn_path = './pretrained/dnn.pth'
fusion_model_save_path = './fusion_model.pth'

# %%
with open(normalization_params_path, 'r') as f:
    normalization_params = json.load(f)

# %% [markdown]
# ## Dataset

# %%
class FusionDataset(Dataset):
    def __init__(self, metadata_path, image_dir, normalization_params, transform=None):
        
        self.metadata = pd.read_csv(metadata_path)

        
        self.image_dir = image_dir
        self.transform = transform

        
        self.labels = self.metadata['target'].values.astype(int)

        
        
        columns_to_drop = [
            "isic_id", "target", "patient_id", "anatom_site_general", "image_type", 
            "tbp_tile_type", "attribution", "copyright_license", "lesion_id", "iddx_full", 
            "iddx_1", "iddx_2", "iddx_3", "iddx_4", "iddx_5", "mel_mitotic_index", 
            "mel_thick_mm", "tbp_lv_dnn_lesion_confidence"
        ]
        metadata_features = self.metadata.drop(columns=columns_to_drop, errors='ignore')


        
        for col, params in normalization_params.items():
            if col in metadata_features.columns:
                col_min = params['min']
                col_max = params['max']
                metadata_features[col] = (metadata_features[col] - col_min) / (col_max - col_min)

        self.metadata_features = metadata_features.values.astype(np.float32)

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        
        isic_id = self.metadata.iloc[idx]['isic_id']
        label = self.labels[idx]
        metadata_features = torch.tensor(self.metadata_features[idx], dtype=torch.float32)

        
        folder = '1' if label == 1 else '0'
        image_path = os.path.join(self.image_dir, folder, f"{isic_id}.jpg")
        image = Image.open(image_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        return image, metadata_features, label

# %%
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  
])

# %%
dataset = FusionDataset(metadata_path=metadata_path, image_dir=image_dir, normalization_params=normalization_params, transform=transform)


train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print(f"Train size: {len(train_loader.dataset)}, Validation size: {len(val_loader.dataset)}, Test size: {len(test_loader.dataset)}")
# Out:
# Train size: 607, Validation size: 75, Test size: 77

# %% [markdown]
# ## Architecture

# %%
class ConformerTinyBinary(nn.Module):
    def __init__(self, img_size=128, num_classes=2, embed_dim=256, num_heads=8, num_transformer_layers=3, dropout=0.2):
        super(ConformerTinyBinary, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout),
            nn.Conv2d(embed_dim, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout),
            nn.Conv2d(embed_dim, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout)
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads),
            num_layers=num_transformer_layers
        )
        self.fc = nn.Linear(embed_dim, num_classes)

    def forward(self, x):
        x = self.conv(x)
        b, c, h, w = x.shape
        x = x.view(b, c, -1).permute(2, 0, 1)  
        x = self.transformer(x)
        x = x.mean(dim=0)  
        return x

# %%
class FeedforwardNN(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(FeedforwardNN, self).__init__()
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(input_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Dropout(0.2),
            torch.nn.Linear(hidden_dim, hidden_dim),
            torch.nn.ReLU(),
            torch.nn.Linear(hidden_dim, output_dim)
        )

    def forward(self, x):
        return self.fc(x)

# %%
class FusionModel(nn.Module):
    def __init__(self, conformer, feedforward, conformer_embed_dim, feedforward_embed_dim, fusion_hidden_dim, output_dim=1, dropout_rate=0.2):
        super(FusionModel, self).__init__()
        self.conformer = conformer
        self.feedforward = feedforward

        
        self.fusion_fc = nn.Sequential(
            nn.Linear(conformer_embed_dim + feedforward_embed_dim, fusion_hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(fusion_hidden_dim, fusion_hidden_dim // 2),  
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(fusion_hidden_dim // 2, fusion_hidden_dim // 4),  
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(fusion_hidden_dim // 4, output_dim)  
        )

    def forward(self, image, metadata):
        
        x = self.conformer.conv(image)  
        b, c, h, w = x.shape
        x = x.view(b, c, -1).permute(2, 0, 1)  
        x = self.conformer.transformer(x)  
        image_embed = x.mean(dim=0)  

        
        metadata_embed = self.feedforward.fc[:-1](metadata)  

        
        fusion_input = torch.cat((image_embed, metadata_embed), dim=1)
        output = self.fusion_fc(fusion_input)
        return output

# %% [markdown]
# ## Init

# %%
conformer = ConformerTinyBinary(embed_dim=256).to(device)
feedforward = FeedforwardNN(input_dim=43, hidden_dim=128, output_dim=2).to(device)


checkpoint_conformer = torch.load(pretrained_conformer_path, map_location=device)
conformer.load_state_dict(checkpoint_conformer['model_state_dict'])


checkpoint_dnn = torch.load(pretrained_dnn_path, map_location=device)
feedforward.load_state_dict(checkpoint_dnn['model_state_dict'])


print("Pretrained models loaded successfully.")
# Out:
# /home/jone/anaconda3/envs/SUTD/lib/python3.9/site-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 6
#       3 feedforward = FeedforwardNN(input_dim=43, hidden_dim=128, output_dim=2).to(device)
#       5 # Load pretrained Conformer weights
# ----> 6 checkpoint_conformer = torch.load(pretrained_conformer_path, map_location=device)
#       7 conformer.load_state_dict(checkpoint_conformer['model_state_dict'])
#       9 # Load pretrained FeedforwardNN weights
#
# File ~/anaconda3/envs/SUTD/lib/python3.9/site-packages/torch/serialization.py:998, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     995 if 'encoding' not in pickle_load_args.keys():
#     996     pickle_load_args['encoding'] = 'utf-8'
# --> 998 with _open_file_like(f, 'rb') as opened_file:
#     999     if _is_zipfile(opened_file):
#    1000         # The zipfile reader is going to advance the current file position.
#    1001         # If we want to actually tail call to torch.jit.load, we need to
#    1002         # reset back to the original position.
#    1003         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/SUTD/lib/python3.9/site-packages/torch/serialization.py:445, in _open_file_like(name_or_buffer, mode)
#     443 def _open_file_like(name_or_buffer, mode):
#     444     if _is_path(name_or_buffer):
# --> 445         return _open_file(name_or_buffer, mode)
#     446     else:
#     447         if 'w' in mode:
#
# File ~/anaconda3/envs/SUTD/lib/python3.9/site-packages/torch/serialization.py:426, in _open_file.__init__(self, name, mode)
#     425 def __init__(self, name, mode):
# --> 426     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: './pretrained/conformer.pth'

# %%
fusion_hidden_dim = 256
dropout_rate = 0.0
num_epochs = 50
learning_rate = 1e-5

fusion_model = FusionModel(
    conformer=conformer,
    feedforward=feedforward,
    conformer_embed_dim=256,
    feedforward_embed_dim=128,
    fusion_hidden_dim=fusion_hidden_dim,
    output_dim=2,
    dropout_rate=dropout_rate
).to(device)

# %% [markdown]
# ## Train

# %%
def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0
    for image, metadata, labels in dataloader:
        image, metadata, labels = image.to(device), metadata.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(image, metadata)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * image.size(0)
        _, preds = torch.max(outputs, 1)
        correct += torch.sum(preds == labels).item()
    return running_loss / len(dataloader.dataset), correct / len(dataloader.dataset)

def validate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        for image, metadata, labels in dataloader:
            image, metadata, labels = image.to(device), metadata.to(device), labels.to(device)
            outputs = model(image, metadata)
            loss = criterion(outputs, labels)
            running_loss += loss.item() * image.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels).item()
    return running_loss / len(dataloader.dataset), correct / len(dataloader.dataset)

# %%
model_dir = "saved_models"
os.makedirs(model_dir, exist_ok=True)
best_model_path = os.path.join(model_dir, "best_model.pth")
params_file_path = os.path.join(model_dir, "model_params.txt")

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(fusion_model.parameters(), lr=learning_rate)


train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
best_val_loss = float("inf")

for epoch in range(num_epochs):
    
    train_loss, train_acc = train_one_epoch(fusion_model, train_loader, criterion, optimizer, device)
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    
    val_loss, val_acc = validate(fusion_model, val_loader, criterion, device)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({
            "epoch": epoch + 1,
            "model_state_dict": fusion_model.state_dict(),
            "optimizer_state_dict": optimizer.state_dict(),
            "val_loss": best_val_loss,
        }, best_model_path)
        print(f"Saved new best model with val loss {val_loss:.4f} at epoch {epoch + 1}")

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# Saved new best model with val loss 0.6761 at epoch 1
# Epoch 1/50 - Train Loss: 0.6910, Train Acc: 0.4975, Val Loss: 0.6761, Val Acc: 0.5733
# Saved new best model with val loss 0.6712 at epoch 2
# Epoch 2/50 - Train Loss: 0.6856, Train Acc: 0.4975, Val Loss: 0.6712, Val Acc: 0.5867
# Saved new best model with val loss 0.6644 at epoch 3
# Epoch 3/50 - Train Loss: 0.6808, Train Acc: 0.5222, Val Loss: 0.6644, Val Acc: 0.7333
# Saved new best model with val loss 0.6565 at epoch 4
# Epoch 4/50 - Train Loss: 0.6744, Train Acc: 0.6392, Val Loss: 0.6565, Val Acc: 0.8533
# Saved new best model with val loss 0.6468 at epoch 5
# Epoch 5/50 - Train Loss: 0.6684, Train Acc: 0.7051, Val Loss: 0.6468, Val Acc: 0.8800
# Saved new best model with val loss 0.6327 at epoch 6
# Epoch 6/50 - Train Loss: 0.6579, Train Acc: 0.7496, Val Loss: 0.6327, Val Acc: 0.8400
# Saved new best model with val loss 0.6189 at epoch 7
# Epoch 7/50 - Train Loss: 0.6481, Train Acc: 0.7644, Val Loss: 0.6189, Val Acc: 0.8400
# Saved new best model with val loss 0.6051 at epoch 8
# Epoch 8/50 - Train Loss: 0.6366, Train Acc: 0.7825, Val Loss: 0.6051, Val Acc: 0.8533
# Saved new best model with val loss 0.5905 at epoch 9
# Epoch 9/50 - Train Loss: 0.6236, Train Acc: 0.8089, Val Loss: 0.5905, Val Acc: 0.8533
# Saved new best model with val loss 0.5785 at epoch 10
# Epoch 10/50 - Train Loss: 0.6109, Train Acc: 0.8089, Val Loss: 0.5785, Val Acc: 0.8933
# Saved new best model with val loss 0.5623 at epoch 11
# Epoch 11/50 - Train Loss: 0.5990, Train Acc: 0.8122, Val Loss: 0.5623, Val Acc: 0.8933
# Saved new best model with val loss 0.5427 at epoch 12
# Epoch 12/50 - Train Loss: 0.5873, Train Acc: 0.8221, Val Loss: 0.5427, Val Acc: 0.8933
# Saved new best model with val loss 0.5292 at epoch 13
# Epoch 13/50 - Train Loss: 0.5721, Train Acc: 0.8237, Val Loss: 0.5292, Val Acc: 0.8933
# Saved new best model with val loss 0.5123 at epoch 14
# Epoch 14/50 - Train Loss: 0.5607, Train Acc: 0.8287, Val Loss: 0.5123, Val Acc: 0.8933
# Saved new best model with val loss 0.4988 at epoch 15
# Epoch 15/50 - Train Loss: 0.5433, Train Acc: 0.8336, Val Loss: 0.4988, Val Acc: 0.8933
# Saved new best model with val loss 0.4861 at epoch 16
# Epoch 16/50 - Train Loss: 0.5332, Train Acc: 0.8353, Val Loss: 0.4861, Val Acc: 0.8933
# Saved new best model with val loss 0.4696 at epoch 17
# Epoch 17/50 - Train Loss: 0.5184, Train Acc: 0.8353, Val Loss: 0.4696, Val Acc: 0.8933
# Saved new best model with val loss 0.4639 at epoch 18
# Epoch 18/50 - Train Loss: 0.5028, Train Acc: 0.8451, Val Loss: 0.4639, Val Acc: 0.8667
# Saved new best model with val loss 0.4497 at epoch 19
# Epoch 19/50 - Train Loss: 0.4921, Train Acc: 0.8451, Val Loss: 0.4497, Val Acc: 0.8667
# Saved new best model with val loss 0.4365 at epoch 20
# Epoch 20/50 - Train Loss: 0.4780, Train Acc: 0.8435, Val Loss: 0.4365, Val Acc: 0.8800
# Saved new best model with val loss 0.4329 at epoch 21
# Epoch 21/50 - Train Loss: 0.4745, Train Acc: 0.8435, Val Loss: 0.4329, Val Acc: 0.8533
# Saved new best model with val loss 0.4280 at epoch 22
# Epoch 22/50 - Train Loss: 0.4615, Train Acc: 0.8418, Val Loss: 0.4280, Val Acc: 0.8533
# Saved new best model with val loss 0.4217 at epoch 23
# Epoch 23/50 - Train Loss: 0.4508, Train Acc: 0.8451, Val Loss: 0.4217, Val Acc: 0.8533
# Saved new best model with val loss 0.4153 at epoch 24
# Epoch 24/50 - Train Loss: 0.4436, Train Acc: 0.8484, Val Loss: 0.4153, Val Acc: 0.8533
# Epoch 25/50 - Train Loss: 0.4383, Train Acc: 0.8451, Val Loss: 0.4161, Val Acc: 0.8533
# Saved new best model with val loss 0.3953 at epoch 26
# Epoch 26/50 - Train Loss: 0.4338, Train Acc: 0.8402, Val Loss: 0.3953, Val Acc: 0.8533
# Saved new best model with val loss 0.3884 at epoch 27
# Epoch 27/50 - Train Loss: 0.4100, Train Acc: 0.8699, Val Loss: 0.3884, Val Acc: 0.8667
# Epoch 28/50 - Train Loss: 0.4133, Train Acc: 0.8616, Val Loss: 0.3997, Val Acc: 0.8533
# Epoch 29/50 - Train Loss: 0.4065, Train Acc: 0.8534, Val Loss: 0.3950, Val Acc: 0.8533
# Epoch 30/50 - Train Loss: 0.3915, Train Acc: 0.8649, Val Loss: 0.4036, Val Acc: 0.8533
# Epoch 31/50 - Train Loss: 0.4014, Train Acc: 0.8468, Val Loss: 0.3948, Val Acc: 0.8533
# Saved new best model with val loss 0.3821 at epoch 32
# Epoch 32/50 - Train Loss: 0.4075, Train Acc: 0.8468, Val Loss: 0.3821, Val Acc: 0.8400
# Epoch 33/50 - Train Loss: 0.3831, Train Acc: 0.8682, Val Loss: 0.3943, Val Acc: 0.8533
# Epoch 34/50 - Train Loss: 0.3823, Train Acc: 0.8534, Val Loss: 0.3880, Val Acc: 0.8533
# Saved new best model with val loss 0.3701 at epoch 35
# Epoch 35/50 - Train Loss: 0.3753, Train Acc: 0.8550, Val Loss: 0.3701, Val Acc: 0.8533
# Epoch 36/50 - Train Loss: 0.3822, Train Acc: 0.8616, Val Loss: 0.3776, Val Acc: 0.8533
# Epoch 37/50 - Train Loss: 0.3795, Train Acc: 0.8468, Val Loss: 0.3893, Val Acc: 0.8533
# Saved new best model with val loss 0.3685 at epoch 38
# Epoch 38/50 - Train Loss: 0.3772, Train Acc: 0.8666, Val Loss: 0.3685, Val Acc: 0.8667
# Epoch 39/50 - Train Loss: 0.3765, Train Acc: 0.8616, Val Loss: 0.3804, Val Acc: 0.8533
# Epoch 40/50 - Train Loss: 0.3603, Train Acc: 0.8731, Val Loss: 0.3714, Val Acc: 0.8533
# Saved new best model with val loss 0.3678 at epoch 41
# Epoch 41/50 - Train Loss: 0.3559, Train Acc: 0.8666, Val Loss: 0.3678, Val Acc: 0.8533
# Epoch 42/50 - Train Loss: 0.3571, Train Acc: 0.8616, Val Loss: 0.3728, Val Acc: 0.8533
# Epoch 43/50 - Train Loss: 0.3451, Train Acc: 0.8715, Val Loss: 0.3810, Val Acc: 0.8533
# Saved new best model with val loss 0.3673 at epoch 44
# Epoch 44/50 - Train Loss: 0.3589, Train Acc: 0.8682, Val Loss: 0.3673, Val Acc: 0.8667
# Epoch 45/50 - Train Loss: 0.3542, Train Acc: 0.8616, Val Loss: 0.3774, Val Acc: 0.8533
# Epoch 46/50 - Train Loss: 0.3687, Train Acc: 0.8468, Val Loss: 0.3817, Val Acc: 0.8533
# Epoch 47/50 - Train Loss: 0.3450, Train Acc: 0.8797, Val Loss: 0.3693, Val Acc: 0.8533
# Epoch 48/50 - Train Loss: 0.3613, Train Acc: 0.8666, Val Loss: 0.3803, Val Acc: 0.8533
# Epoch 49/50 - Train Loss: 0.3441, Train Acc: 0.8699, Val Loss: 0.3820, Val Acc: 0.8533
# Epoch 50/50 - Train Loss: 0.3332, Train Acc: 0.8863, Val Loss: 0.3894, Val Acc: 0.8533

# %% [markdown]
# ## Evaluation

# %%
def custom_metric(y_true, y_pred_proba, min_tpr=0.8):
    """
    Calculate the partial AUC (pAUC) based on a minimum TPR threshold.
    """
    y_true = np.array(y_true)
    y_pred_proba = np.array(y_pred_proba)

    max_fpr = 1 - min_tpr
    v_gt = abs(y_true - 1)  
    v_pred = 1.0 - y_pred_proba  

    pauc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)
    pauc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (pauc_scaled - 0.5)

    return pauc

# %%
print(f"Loading best model from: {best_model_path}")
checkpoint = torch.load(best_model_path)
fusion_model.load_state_dict(checkpoint["model_state_dict"])

fusion_model.eval()
y_true, y_pred, y_pred_proba = [], [], []

test_loss, test_corrects = 0.0, 0
with torch.no_grad():
    for image, metadata, labels in test_loader:
        image, metadata, labels = image.to(device), metadata.to(device), labels.to(device)
        outputs = fusion_model(image, metadata)
        loss = criterion(outputs, labels)
        test_loss += loss.item() * image.size(0)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())
        y_pred_proba.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())
        test_corrects += torch.sum(preds == labels).item()


test_loss /= len(test_loader.dataset)
test_accuracy = test_corrects / len(test_loader.dataset)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
print("Test Classification Report:")
print(classification_report(y_true, y_pred))

partial_auc = custom_metric(y_true, y_pred_proba)
print(f"Partial AUC (pAUC): {partial_auc:.4f}")
# Out:
# Loading best model from: saved_models/best_model.pth
# Test Loss: 0.3813, Test Accuracy: 0.8442
# Test Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82        33
#            1       0.88      0.84      0.86        44
#
#     accuracy                           0.84        77
#    macro avg       0.84      0.84      0.84        77
# weighted avg       0.85      0.84      0.84        77
#
# Partial AUC (pAUC): 0.1435

# %% [markdown]
# ## Plotting

# %%
def save_plot(values, title, xlabel, ylabel, filename, labels=None, extra=None):
    plt.figure(figsize=(10, 6))
    for idx, val in enumerate(values):
        plt.plot(range(1, len(val) + 1), val, label=labels[idx] if labels else f"Curve {idx + 1}")
    if extra:
        for line in extra:
            plt.axhline(**line)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid()
    plt.savefig(filename, bbox_inches="tight")
    plt.show()
    print(f"Saved plot: {filename}")


save_plot(
    [train_losses, val_losses],
    "Train vs Validation Loss",
    "Epochs",
    "Loss",
    os.path.join(model_dir, "train_val_loss.png"),
    labels=["Train Loss", "Validation Loss"],
    extra=[{"y": test_loss, "color": "r", "linestyle": "--", "label": f"Test Loss: {test_loss:.4f}"}],
)


save_plot(
    [train_accuracies, val_accuracies],
    "Train vs Validation Accuracy",
    "Epochs",
    "Accuracy",
    os.path.join(model_dir, "train_val_accuracy.png"),
    labels=["Train Accuracy", "Validation Accuracy"],
    extra=[{"y": test_accuracy, "color": "r", "linestyle": "--", "label": f"Test Accuracy: {test_accuracy:.4f}"}],
)


fpr, tpr, _ = roc_curve(y_true, y_pred_proba)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc_score(y_true, y_pred_proba):.4f})", linewidth=2)
plt.fill_between(fpr, tpr, alpha=0.2, label=f"pAUC = {partial_auc:.4f} (FPR ≤ 0.2)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.grid(True)
roc_curve_path = os.path.join(model_dir, "roc_curve.png")
plt.savefig(roc_curve_path, bbox_inches="tight")
plt.show()
print(f"ROC Curve saved at: {roc_curve_path}")


with open(params_file_path, "w") as f:
    f.write("Model Architecture:\n")
    f.write(str(fusion_model) + "\n\n")
    f.write("Hyperparameters:\n")
    f.write(f"Batch Size: {batch_size}\n")
    f.write(f"Learning Rate: {optimizer.param_groups[0]['lr']}\n")
    f.write(f"Number of Epochs: {num_epochs}\n")
    f.write(f"Dropout Rate: {dropout_rate}\n")  
    f.write(f"Learning Rate: {learning_rate}\n")
    f.write("Optimizer: Adam\n")
    f.write("Loss Function: CrossEntropyLoss\n\n")
    f.write("Training Results:\n")
    f.write(f"Final Train Loss: {train_losses[-1]:.4f}\n")
    f.write(f"Final Train Accuracy: {train_accuracies[-1]:.4f}\n\n")
    f.write("Validation Results:\n")
    f.write(f"Best Validation Loss: {best_val_loss:.4f}\n")
    f.write(f"Best Validation Accuracy: {max(val_accuracies):.4f}\n\n")
    f.write("Test Results:\n")
    f.write(f"Test Loss: {test_loss:.4f}\n")
    f.write(f"Test Accuracy: {test_accuracy:.4f}\n")
    f.write(f"Partial AUC (pAUC): {partial_auc:.4f}\n")
    f.write(f"ROC AUC: {roc_auc_score(y_true, y_pred_proba):.4f}\n")
print(f"Model parameters saved to {params_file_path}")
# Out:
# Saved plot: saved_models/train_val_loss.png
# Saved plot: saved_models/train_val_accuracy.png
# ROC Curve saved at: saved_models/roc_curve.png
# Model parameters saved to saved_models/model_params.txt
