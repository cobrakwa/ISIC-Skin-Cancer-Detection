# %% [markdown]
# ## Imports

# %%
import os
import random
import glob
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Set random seed for reproducibility

# %%
SEED = 42
torch.manual_seed(SEED)
random.seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Data Loading

# %%
from sklearn.model_selection import train_test_split
from collections import Counter


data_dir = "../data/balanced_data"


train_transform = transforms.Compose([
    transforms.Resize((128, 128)),  
    transforms.RandomHorizontalFlip(p=0.5),  
    transforms.RandomRotation(degrees=15),  
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  
])


test_transform = transforms.Compose([
    transforms.Resize((128, 128)),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])  
])


dataset = datasets.ImageFolder(root=data_dir, transform=test_transform)  
labels = [label for _, label in dataset.samples]


dataset = datasets.ImageFolder(root=data_dir, transform=test_transform)  
labels = [label for _, label in dataset.samples]
filenames = [os.path.basename(path) for path, _ in dataset.samples]


label_1_indices = [i for i, label in enumerate(labels) if label == 1]
label_0_indices = [i for i, label in enumerate(labels) if label == 0]


label_1_test_size = max(1, int(0.1 * len(label_1_indices)))  
label_0_test_size = max(1, int(0.1 * len(label_0_indices)))


original_label_1_indices = [i for i in label_1_indices if filenames[i].startswith("original")]
if len(original_label_1_indices) >= label_1_test_size:
    label_1_test_indices = original_label_1_indices[:label_1_test_size]
else:
    label_1_test_indices = original_label_1_indices + label_1_indices[:label_1_test_size - len(original_label_1_indices)]


label_0_test_indices = label_0_indices[:label_0_test_size]


remaining_label_1_indices = list(set(label_1_indices) - set(label_1_test_indices))
remaining_label_0_indices = list(set(label_0_indices) - set(label_0_test_indices))


label_1_train_indices, label_1_val_indices = train_test_split(
    remaining_label_1_indices, test_size=0.2, stratify=[labels[i] for i in remaining_label_1_indices], random_state=42
)


label_0_train_indices, label_0_val_indices = train_test_split(
    remaining_label_0_indices, test_size=0.2, stratify=[labels[i] for i in remaining_label_0_indices], random_state=42
)


train_indices = label_1_train_indices + label_0_train_indices
val_indices = label_1_val_indices + label_0_val_indices
test_indices = label_1_test_indices + label_0_test_indices


train_dataset = torch.utils.data.Subset(datasets.ImageFolder(root=data_dir, transform=train_transform), train_indices)
val_dataset = torch.utils.data.Subset(datasets.ImageFolder(root=data_dir, transform=val_transform), val_indices)
test_dataset = torch.utils.data.Subset(datasets.ImageFolder(root=data_dir, transform=test_transform), test_indices)


batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)


train_counts = Counter([labels[i] for i in train_indices])
val_counts = Counter([labels[i] for i in val_indices])
test_counts = Counter([labels[i] for i in test_indices])

print(f"Train class distribution: {train_counts}")
print(f"Validation class distribution: {val_counts}")
print(f"Test class distribution: {test_counts}")
# Out:
# Train class distribution: Counter({1: 283, 0: 283})
# Validation class distribution: Counter({1: 71, 0: 71})
# Test class distribution: Counter({1: 39, 0: 39})

# %% [markdown]
# ## Architecture Definition

# %%
class ConformerTinyBinary(nn.Module):
    def __init__(self, img_size=128, num_classes=5, embed_dim=256, num_heads=8, num_transformer_layers=3, dropout=0.2):
        super(ConformerTinyBinary, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(3, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout),  

            nn.Conv2d(embed_dim, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout),  

            nn.Conv2d(embed_dim, embed_dim, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(embed_dim),
            nn.ReLU(),
            nn.Dropout2d(dropout)   
        )
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads),
            num_layers=num_transformer_layers
        )
        self.fc = nn.Linear(embed_dim, num_classes)

    def forward(self, x):
        x = self.conv(x)
        b, c, h, w = x.shape
        x = x.view(b, c, -1).permute(2, 0, 1)  
        x = self.transformer(x)
        x = x.mean(dim=0)  
        x = self.fc(x)
        return x

# %% [markdown]
# ## Function Definition

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc, classification_report
from scipy import interp

model_dir = 'scratch_test_augmentless/saved_models'
os.makedirs(model_dir, exist_ok=True)


def save_model(epoch, model, optimizer, path, best=False):
    state = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
    }
    torch.save(state, path)
    if best:
        best_path = os.path.join(model_dir, f"best_model_epoch{epoch}.pth")
        torch.save(state, best_path)

def load_model(path, model, optimizer):
    checkpoint = torch.load(path)
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    return checkpoint['epoch']


def train_one_epoch(model, dataloader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
    return running_loss / len(dataloader.dataset)


def validate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, preds = torch.max(outputs, 1)
            correct += torch.sum(preds == labels).item()
    return running_loss / len(dataloader.dataset), correct / len(dataloader.dataset)

def custom_metric(y_true, y_pred, min_tpr=0.8):
    """
    Calculate the partial AUC (pAUC) based on a minimum TPR threshold.

    Args:
        y_true (array): True binary labels.
        y_pred (array): Predicted probabilities.
        min_tpr (float): Minimum TPR threshold (default: 0.8).

    Returns:
        float: Scaled pAUC value.
    """
    
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    max_fpr = 1 - min_tpr  
    v_gt = abs(y_true - 1)  
    v_pred = 1.0 - y_pred  

    
    pauc_scaled = roc_auc_score(v_gt, v_pred, max_fpr=max_fpr)

    
    pauc = 0.5 * max_fpr**2 + (max_fpr - 0.5 * max_fpr**2) / (1.0 - 0.5) * (pauc_scaled - 0.5)

    return pauc



def compute_auc_and_roc(model, dataloader, device, min_tpr=0.8):
    """
    Computes the ROC, AUC, and partial AUC for the given model and dataloader.
    
    Args:
        model: The PyTorch model to evaluate.
        dataloader: DataLoader for evaluation data.
        device: Device to run the computations on (CPU or GPU).
        min_tpr: Minimum TPR threshold for partial AUC computation.
    
    Returns:
        fpr: False positive rates.
        tpr: True positive rates.
        roc_auc: Full area under the ROC curve.
        partial_auc: Partial area under the ROC curve for TPR >= min_tpr.
        y_true: Ground truth labels.
        y_scores: Predicted scores for the positive class.
    """
    model.eval()
    y_true = []
    y_scores = []

    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            
            probabilities = torch.softmax(outputs, dim=1)[:, 1]
            
            y_true.extend(labels.cpu().numpy())
            y_scores.extend(probabilities.cpu().numpy())
    
    
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)
    roc_auc = roc_auc_score(y_true, y_scores)  

    
    normalized_pauc = custom_metric(y_true, y_scores, min_tpr=min_tpr)

    return fpr, tpr, roc_auc, normalized_pauc, y_true, y_scores

# %% [markdown]
# ## Model Init

# %%
fine_tuned_model = ConformerTinyBinary(num_classes=2)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
fine_tuned_model = fine_tuned_model.to(device)
# Out:
# Device: cuda
# c:\Users\jonec\miniconda3\envs\general_ai\lib\site-packages\torch\nn\modules\transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
learning_rate = 1e-4  
num_epochs = 100
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(fine_tuned_model.parameters(), lr=learning_rate)

# %% [markdown]
# ## Training

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

best_val_loss = float('inf')

val_aucs = []
val_paucs = []

for epoch in range(num_epochs):
    
    train_loss = train_one_epoch(fine_tuned_model, train_loader, criterion, optimizer, device)
    train_losses.append(train_loss)

    
    train_loss, train_acc = validate(fine_tuned_model, train_loader, criterion, device)
    train_accuracies.append(train_acc)

    
    val_loss, val_acc = validate(fine_tuned_model, val_loader, criterion, device)
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    
    fpr, tpr, roc_auc, partial_auc, _, _ = compute_auc_and_roc(fine_tuned_model, val_loader, device, min_tpr=0.8)

    val_aucs.append(roc_auc)
    val_paucs.append(partial_auc)

    print(f"Epoch {epoch+1}/{num_epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}, Val AUC: {roc_auc:.4f}, Val pAUC: {partial_auc:.4f}")

    
    save_model(epoch, fine_tuned_model, optimizer, os.path.join(model_dir, f"epoch{epoch+1}.pth"))
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        save_model(epoch+1, fine_tuned_model, optimizer, os.path.join(model_dir, f"best_model_epoch{epoch+1}.pth"), best=True)
# Out:
# c:\Users\jonec\miniconda3\envs\general_ai\lib\site-packages\torch\nn\functional.py:5560: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:555.)
#   attn_output = scaled_dot_product_attention(q, k, v, attn_mask, dropout_p, is_causal)
# Epoch 1/100 - Train Loss: 0.7435, Train Acc: 0.5000, Val Loss: 0.7423, Val Acc: 0.5000, Val AUC: 0.5201, Val pAUC: 0.0293
# Epoch 2/100 - Train Loss: 0.7021, Train Acc: 0.4947, Val Loss: 0.6914, Val Acc: 0.4930, Val AUC: 0.5281, Val pAUC: 0.0368
# Epoch 3/100 - Train Loss: 0.7670, Train Acc: 0.5088, Val Loss: 0.7847, Val Acc: 0.5000, Val AUC: 0.5562, Val pAUC: 0.0387
# Epoch 4/100 - Train Loss: 0.7406, Train Acc: 0.5141, Val Loss: 0.7625, Val Acc: 0.5141, Val AUC: 0.5414, Val pAUC: 0.0243
# Epoch 5/100 - Train Loss: 0.7017, Train Acc: 0.5442, Val Loss: 0.7079, Val Acc: 0.5423, Val AUC: 0.5705, Val pAUC: 0.0370
# Epoch 6/100 - Train Loss: 0.6901, Train Acc: 0.5512, Val Loss: 0.6850, Val Acc: 0.4789, Val AUC: 0.5475, Val pAUC: 0.0352
# Epoch 7/100 - Train Loss: 0.6773, Train Acc: 0.5442, Val Loss: 0.6843, Val Acc: 0.5211, Val AUC: 0.6031, Val pAUC: 0.0334
# Epoch 8/100 - Train Loss: 0.6701, Train Acc: 0.6007, Val Loss: 0.6766, Val Acc: 0.5563, Val AUC: 0.5838, Val pAUC: 0.0353
# Epoch 9/100 - Train Loss: 0.6703, Train Acc: 0.5954, Val Loss: 0.6853, Val Acc: 0.5282, Val AUC: 0.5610, Val pAUC: 0.0372
# Epoch 10/100 - Train Loss: 0.6544, Train Acc: 0.6025, Val Loss: 0.6777, Val Acc: 0.5141, Val AUC: 0.5664, Val pAUC: 0.0393
# Epoch 11/100 - Train Loss: 0.6582, Train Acc: 0.5901, Val Loss: 0.6727, Val Acc: 0.5634, Val AUC: 0.6052, Val pAUC: 0.0407
# Epoch 12/100 - Train Loss: 0.6649, Train Acc: 0.5919, Val Loss: 0.6699, Val Acc: 0.5775, Val AUC: 0.6019, Val pAUC: 0.0400
# Epoch 13/100 - Train Loss: 0.6913, Train Acc: 0.5936, Val Loss: 0.6629, Val Acc: 0.5563, Val AUC: 0.6286, Val pAUC: 0.0422
# Epoch 14/100 - Train Loss: 0.6859, Train Acc: 0.5565, Val Loss: 0.6951, Val Acc: 0.5282, Val AUC: 0.6090, Val pAUC: 0.0379
# Epoch 15/100 - Train Loss: 0.6846, Train Acc: 0.5848, Val Loss: 0.6605, Val Acc: 0.6056, Val AUC: 0.6572, Val pAUC: 0.0524
# Epoch 16/100 - Train Loss: 0.6585, Train Acc: 0.5830, Val Loss: 0.6700, Val Acc: 0.5634, Val AUC: 0.6429, Val pAUC: 0.0468
# Epoch 17/100 - Train Loss: 0.6720, Train Acc: 0.5654, Val Loss: 0.7011, Val Acc: 0.5352, Val AUC: 0.5973, Val pAUC: 0.0533
# Epoch 18/100 - Train Loss: 0.6756, Train Acc: 0.5601, Val Loss: 0.6844, Val Acc: 0.5423, Val AUC: 0.5985, Val pAUC: 0.0331
# Epoch 19/100 - Train Loss: 0.6580, Train Acc: 0.5901, Val Loss: 0.6732, Val Acc: 0.5423, Val AUC: 0.6582, Val pAUC: 0.0607
# Epoch 20/100 - Train Loss: 0.6656, Train Acc: 0.5813, Val Loss: 0.6836, Val Acc: 0.5704, Val AUC: 0.6072, Val pAUC: 0.0317
# Epoch 21/100 - Train Loss: 0.6390, Train Acc: 0.6219, Val Loss: 0.6494, Val Acc: 0.6127, Val AUC: 0.6921, Val pAUC: 0.0703
# Epoch 22/100 - Train Loss: 0.6407, Train Acc: 0.6060, Val Loss: 0.6550, Val Acc: 0.5986, Val AUC: 0.6747, Val pAUC: 0.0633
# Epoch 23/100 - Train Loss: 0.6527, Train Acc: 0.6095, Val Loss: 0.6400, Val Acc: 0.6620, Val AUC: 0.6858, Val pAUC: 0.0596
# Epoch 24/100 - Train Loss: 0.6255, Train Acc: 0.6502, Val Loss: 0.6520, Val Acc: 0.5775, Val AUC: 0.6651, Val pAUC: 0.0563
# Epoch 25/100 - Train Loss: 0.6366, Train Acc: 0.6184, Val Loss: 0.6741, Val Acc: 0.5775, Val AUC: 0.6461, Val pAUC: 0.0443
# Epoch 26/100 - Train Loss: 0.6147, Train Acc: 0.6731, Val Loss: 0.6587, Val Acc: 0.5986, Val AUC: 0.6707, Val pAUC: 0.0510
# Epoch 27/100 - Train Loss: 0.6469, Train Acc: 0.6307, Val Loss: 0.6537, Val Acc: 0.6338, Val AUC: 0.6830, Val pAUC: 0.0647
# Epoch 28/100 - Train Loss: 0.6295, Train Acc: 0.6378, Val Loss: 0.6493, Val Acc: 0.6620, Val AUC: 0.6872, Val pAUC: 0.0579
# Epoch 29/100 - Train Loss: 0.6028, Train Acc: 0.6767, Val Loss: 0.6409, Val Acc: 0.6056, Val AUC: 0.6983, Val pAUC: 0.0642
# Epoch 30/100 - Train Loss: 0.6351, Train Acc: 0.6343, Val Loss: 0.6613, Val Acc: 0.5775, Val AUC: 0.6608, Val pAUC: 0.0455
# Epoch 31/100 - Train Loss: 0.6030, Train Acc: 0.6731, Val Loss: 0.6345, Val Acc: 0.6620, Val AUC: 0.7139, Val pAUC: 0.0578
# Epoch 32/100 - Train Loss: 0.6096, Train Acc: 0.6608, Val Loss: 0.6663, Val Acc: 0.6831, Val AUC: 0.7276, Val pAUC: 0.0711
# Epoch 33/100 - Train Loss: 0.5670, Train Acc: 0.7191, Val Loss: 0.6376, Val Acc: 0.6338, Val AUC: 0.7012, Val pAUC: 0.0573
# Epoch 34/100 - Train Loss: 0.5374, Train Acc: 0.7367, Val Loss: 0.6471, Val Acc: 0.6690, Val AUC: 0.7036, Val pAUC: 0.0456
# Epoch 35/100 - Train Loss: 0.5593, Train Acc: 0.7226, Val Loss: 0.6270, Val Acc: 0.6831, Val AUC: 0.7391, Val pAUC: 0.0620
# Epoch 36/100 - Train Loss: 0.5269, Train Acc: 0.7527, Val Loss: 0.6209, Val Acc: 0.6690, Val AUC: 0.7584, Val pAUC: 0.0766
# Epoch 37/100 - Train Loss: 0.6932, Train Acc: 0.6237, Val Loss: 0.7356, Val Acc: 0.6197, Val AUC: 0.7324, Val pAUC: 0.0820
# Epoch 38/100 - Train Loss: 0.6119, Train Acc: 0.6678, Val Loss: 0.6536, Val Acc: 0.6761, Val AUC: 0.7300, Val pAUC: 0.0832
# Epoch 39/100 - Train Loss: 0.4956, Train Acc: 0.7827, Val Loss: 0.6020, Val Acc: 0.6831, Val AUC: 0.7512, Val pAUC: 0.0743
# Epoch 40/100 - Train Loss: 0.5061, Train Acc: 0.7562, Val Loss: 0.5868, Val Acc: 0.7183, Val AUC: 0.7854, Val pAUC: 0.0889
# Epoch 41/100 - Train Loss: 0.5182, Train Acc: 0.7597, Val Loss: 0.5708, Val Acc: 0.6901, Val AUC: 0.7907, Val pAUC: 0.0917
# Epoch 42/100 - Train Loss: 0.5280, Train Acc: 0.7385, Val Loss: 0.6165, Val Acc: 0.6972, Val AUC: 0.7838, Val pAUC: 0.0830
# Epoch 43/100 - Train Loss: 0.5336, Train Acc: 0.7491, Val Loss: 0.6136, Val Acc: 0.6761, Val AUC: 0.7826, Val pAUC: 0.0876
# Epoch 44/100 - Train Loss: 0.4880, Train Acc: 0.7703, Val Loss: 0.5431, Val Acc: 0.7465, Val AUC: 0.8074, Val pAUC: 0.0893
# Epoch 45/100 - Train Loss: 0.5602, Train Acc: 0.7297, Val Loss: 0.6622, Val Acc: 0.6972, Val AUC: 0.7911, Val pAUC: 0.0839
# Epoch 46/100 - Train Loss: 0.5126, Train Acc: 0.7580, Val Loss: 0.6187, Val Acc: 0.7113, Val AUC: 0.8127, Val pAUC: 0.0886
# Epoch 47/100 - Train Loss: 0.5497, Train Acc: 0.7297, Val Loss: 0.6023, Val Acc: 0.7465, Val AUC: 0.8207, Val pAUC: 0.0941
# Epoch 48/100 - Train Loss: 0.4759, Train Acc: 0.7827, Val Loss: 0.5483, Val Acc: 0.7394, Val AUC: 0.8070, Val pAUC: 0.0937
# Epoch 49/100 - Train Loss: 0.4902, Train Acc: 0.7739, Val Loss: 0.5443, Val Acc: 0.7676, Val AUC: 0.8042, Val pAUC: 0.0940
# Epoch 50/100 - Train Loss: 0.5142, Train Acc: 0.7297, Val Loss: 0.5747, Val Acc: 0.7113, Val AUC: 0.8110, Val pAUC: 0.0916
# Epoch 51/100 - Train Loss: 0.4594, Train Acc: 0.8057, Val Loss: 0.5166, Val Acc: 0.7746, Val AUC: 0.8552, Val pAUC: 0.1017
# Epoch 52/100 - Train Loss: 0.4612, Train Acc: 0.7862, Val Loss: 0.4838, Val Acc: 0.7887, Val AUC: 0.8540, Val pAUC: 0.1037
# Epoch 53/100 - Train Loss: 0.5290, Train Acc: 0.7297, Val Loss: 0.5846, Val Acc: 0.7394, Val AUC: 0.8302, Val pAUC: 0.0960
# Epoch 54/100 - Train Loss: 0.5831, Train Acc: 0.7120, Val Loss: 0.7045, Val Acc: 0.6761, Val AUC: 0.8322, Val pAUC: 0.0988
# Epoch 55/100 - Train Loss: 0.4982, Train Acc: 0.7562, Val Loss: 0.5704, Val Acc: 0.7535, Val AUC: 0.8177, Val pAUC: 0.0946
# Epoch 56/100 - Train Loss: 0.4563, Train Acc: 0.8004, Val Loss: 0.5169, Val Acc: 0.7465, Val AUC: 0.8328, Val pAUC: 0.0943
# Epoch 57/100 - Train Loss: 0.4723, Train Acc: 0.7809, Val Loss: 0.4921, Val Acc: 0.7535, Val AUC: 0.8427, Val pAUC: 0.1018
# Epoch 58/100 - Train Loss: 0.4873, Train Acc: 0.7774, Val Loss: 0.5290, Val Acc: 0.7746, Val AUC: 0.8475, Val pAUC: 0.1081
# Epoch 59/100 - Train Loss: 0.4173, Train Acc: 0.8304, Val Loss: 0.4730, Val Acc: 0.8028, Val AUC: 0.8592, Val pAUC: 0.1148
# Epoch 60/100 - Train Loss: 0.4454, Train Acc: 0.7915, Val Loss: 0.5196, Val Acc: 0.7817, Val AUC: 0.8383, Val pAUC: 0.1108
# Epoch 61/100 - Train Loss: 0.4434, Train Acc: 0.8004, Val Loss: 0.4894, Val Acc: 0.7606, Val AUC: 0.8475, Val pAUC: 0.1066
# Epoch 62/100 - Train Loss: 0.4129, Train Acc: 0.8269, Val Loss: 0.4838, Val Acc: 0.7958, Val AUC: 0.8530, Val pAUC: 0.1133
# Epoch 63/100 - Train Loss: 0.4752, Train Acc: 0.7827, Val Loss: 0.4869, Val Acc: 0.7676, Val AUC: 0.8722, Val pAUC: 0.1178
# Epoch 64/100 - Train Loss: 0.4494, Train Acc: 0.7898, Val Loss: 0.5051, Val Acc: 0.7676, Val AUC: 0.8637, Val pAUC: 0.1127
# Epoch 65/100 - Train Loss: 0.5093, Train Acc: 0.7615, Val Loss: 0.6281, Val Acc: 0.7113, Val AUC: 0.8417, Val pAUC: 0.0968
# Epoch 66/100 - Train Loss: 0.4515, Train Acc: 0.7951, Val Loss: 0.5938, Val Acc: 0.6901, Val AUC: 0.8294, Val pAUC: 0.0908
# Epoch 67/100 - Train Loss: 0.4487, Train Acc: 0.8057, Val Loss: 0.4814, Val Acc: 0.7817, Val AUC: 0.8554, Val pAUC: 0.1051
# Epoch 68/100 - Train Loss: 0.5060, Train Acc: 0.7580, Val Loss: 0.5458, Val Acc: 0.7394, Val AUC: 0.8657, Val pAUC: 0.1112
# Epoch 69/100 - Train Loss: 0.4577, Train Acc: 0.7845, Val Loss: 0.4778, Val Acc: 0.7817, Val AUC: 0.8609, Val pAUC: 0.1059
# Epoch 70/100 - Train Loss: 0.4087, Train Acc: 0.8180, Val Loss: 0.4886, Val Acc: 0.7887, Val AUC: 0.8478, Val pAUC: 0.0964
# Epoch 71/100 - Train Loss: 0.4622, Train Acc: 0.7827, Val Loss: 0.5537, Val Acc: 0.7746, Val AUC: 0.8397, Val pAUC: 0.1035
# Epoch 72/100 - Train Loss: 0.4103, Train Acc: 0.8286, Val Loss: 0.5518, Val Acc: 0.7606, Val AUC: 0.8433, Val pAUC: 0.1037
# Epoch 73/100 - Train Loss: 0.4216, Train Acc: 0.8233, Val Loss: 0.6423, Val Acc: 0.6831, Val AUC: 0.8282, Val pAUC: 0.0947
# Epoch 74/100 - Train Loss: 0.4164, Train Acc: 0.8021, Val Loss: 0.5626, Val Acc: 0.7394, Val AUC: 0.8478, Val pAUC: 0.0958
# Epoch 75/100 - Train Loss: 0.4407, Train Acc: 0.7933, Val Loss: 0.5364, Val Acc: 0.7606, Val AUC: 0.8397, Val pAUC: 0.1047
# Epoch 76/100 - Train Loss: 0.4244, Train Acc: 0.8251, Val Loss: 0.5037, Val Acc: 0.7817, Val AUC: 0.8383, Val pAUC: 0.1099
# Epoch 77/100 - Train Loss: 0.4436, Train Acc: 0.8057, Val Loss: 0.5478, Val Acc: 0.7606, Val AUC: 0.8490, Val pAUC: 0.1049
# Epoch 78/100 - Train Loss: 0.4408, Train Acc: 0.8074, Val Loss: 0.5039, Val Acc: 0.7746, Val AUC: 0.8520, Val pAUC: 0.1071
# Epoch 79/100 - Train Loss: 0.3868, Train Acc: 0.8269, Val Loss: 0.4805, Val Acc: 0.8028, Val AUC: 0.8534, Val pAUC: 0.1020
# Epoch 80/100 - Train Loss: 0.4717, Train Acc: 0.7703, Val Loss: 0.6860, Val Acc: 0.6690, Val AUC: 0.8338, Val pAUC: 0.0957
# Epoch 81/100 - Train Loss: 0.4213, Train Acc: 0.8057, Val Loss: 0.5267, Val Acc: 0.7676, Val AUC: 0.8449, Val pAUC: 0.1036
# Epoch 82/100 - Train Loss: 0.3982, Train Acc: 0.8339, Val Loss: 0.5010, Val Acc: 0.7887, Val AUC: 0.8443, Val pAUC: 0.1068
# Epoch 83/100 - Train Loss: 0.4132, Train Acc: 0.8004, Val Loss: 0.5006, Val Acc: 0.7676, Val AUC: 0.8488, Val pAUC: 0.1046
# Epoch 84/100 - Train Loss: 0.4445, Train Acc: 0.7915, Val Loss: 0.5225, Val Acc: 0.7746, Val AUC: 0.8582, Val pAUC: 0.1109
# Epoch 85/100 - Train Loss: 0.4335, Train Acc: 0.7951, Val Loss: 0.4871, Val Acc: 0.7817, Val AUC: 0.8623, Val pAUC: 0.1063
# Epoch 86/100 - Train Loss: 0.4204, Train Acc: 0.8127, Val Loss: 0.5069, Val Acc: 0.7606, Val AUC: 0.8619, Val pAUC: 0.1070
# Epoch 87/100 - Train Loss: 0.4105, Train Acc: 0.8092, Val Loss: 0.5162, Val Acc: 0.7606, Val AUC: 0.8560, Val pAUC: 0.1076
# Epoch 88/100 - Train Loss: 0.4145, Train Acc: 0.8251, Val Loss: 0.4679, Val Acc: 0.7958, Val AUC: 0.8679, Val pAUC: 0.1110
# Epoch 89/100 - Train Loss: 0.4017, Train Acc: 0.8392, Val Loss: 0.5013, Val Acc: 0.7465, Val AUC: 0.8619, Val pAUC: 0.1061
# Epoch 90/100 - Train Loss: 0.4285, Train Acc: 0.8021, Val Loss: 0.5805, Val Acc: 0.7183, Val AUC: 0.8318, Val pAUC: 0.0867
# Epoch 91/100 - Train Loss: 0.4075, Train Acc: 0.8286, Val Loss: 0.5125, Val Acc: 0.8099, Val AUC: 0.8435, Val pAUC: 0.0965
# Epoch 92/100 - Train Loss: 0.3999, Train Acc: 0.8322, Val Loss: 0.5030, Val Acc: 0.7817, Val AUC: 0.8566, Val pAUC: 0.1046
# Epoch 93/100 - Train Loss: 0.4284, Train Acc: 0.8092, Val Loss: 0.5670, Val Acc: 0.7324, Val AUC: 0.8568, Val pAUC: 0.1022
# Epoch 94/100 - Train Loss: 0.3886, Train Acc: 0.8145, Val Loss: 0.4969, Val Acc: 0.7958, Val AUC: 0.8605, Val pAUC: 0.1029
# Epoch 95/100 - Train Loss: 0.3843, Train Acc: 0.8375, Val Loss: 0.5112, Val Acc: 0.7746, Val AUC: 0.8417, Val pAUC: 0.0931
# Epoch 96/100 - Train Loss: 0.4180, Train Acc: 0.8039, Val Loss: 0.5574, Val Acc: 0.7324, Val AUC: 0.8524, Val pAUC: 0.1026
# Epoch 97/100 - Train Loss: 0.3929, Train Acc: 0.8180, Val Loss: 0.5102, Val Acc: 0.7394, Val AUC: 0.8504, Val pAUC: 0.0942
# Epoch 98/100 - Train Loss: 0.3909, Train Acc: 0.8339, Val Loss: 0.4845, Val Acc: 0.7606, Val AUC: 0.8576, Val pAUC: 0.1026
# Epoch 99/100 - Train Loss: 0.3830, Train Acc: 0.8322, Val Loss: 0.4889, Val Acc: 0.7746, Val AUC: 0.8578, Val pAUC: 0.1090
# Epoch 100/100 - Train Loss: 0.4020, Train Acc: 0.8322, Val Loss: 0.5415, Val Acc: 0.7746, Val AUC: 0.8463, Val pAUC: 0.0952

# %% [markdown]
# ## Testing

# %%
import glob
import re
import os


model_files = glob.glob(os.path.join(model_dir, "best_model_epoch*.pth"))
if not model_files:
    raise FileNotFoundError(f"No model files found in {model_dir} matching pattern 'best_model_epoch*.pth'")


epoch_numbers = [
    int(re.search(r"best_model_epoch(\d+)\.pth", os.path.basename(file)).group(1))
    for file in model_files
]


highest_epoch = max(epoch_numbers)
print(f"Highest epoch found: {highest_epoch}")


best_model_path = os.path.join(model_dir, f"best_model_epoch{highest_epoch}.pth")
print(f"Loading best model from: {best_model_path}")
checkpoint = torch.load(best_model_path)
fine_tuned_model.load_state_dict(checkpoint['model_state_dict'])


fpr, tpr, roc_auc, partial_auc, y_true, y_scores = compute_auc_and_roc(fine_tuned_model, test_loader, device, min_tpr=0.8)


y_pred = [1 if score >= 0.5 else 0 for score in y_scores]
class_report = classification_report(y_true, y_pred, target_names=dataset.classes)
print("Classification Report:")
print(class_report)


report_path = os.path.join(model_dir, "classification_report.txt")
with open(report_path, "w") as report_file:
    report_file.write(class_report)

print(f"Classification report saved at: {report_path}")


plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}", linewidth=2)
plt.fill_between(fpr, tpr, alpha=0.2, label=f"pAUC = {partial_auc:.4f} (FPR ≥ 0.8)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Test Set)")
plt.legend(loc="lower right")
plt.grid(True)


roc_plot_path = os.path.join(model_dir, "test_roc_curve.png")
plt.savefig(roc_plot_path, bbox_inches="tight")
plt.show()

print(f"Test ROC Curve plot saved at: {roc_plot_path}")
# Out:
# Highest epoch found: 88
# Loading best model from: scratch_test_augmentless/saved_models\best_model_epoch88.pth
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.72      0.78        39
#            1       0.76      0.87      0.81        39
#
#     accuracy                           0.79        78
#    macro avg       0.80      0.79      0.79        78
# weighted avg       0.80      0.79      0.79        78
#
# Classification report saved at: scratch_test_augmentless/saved_models\classification_report.txt
# C:\Users\jonec\AppData\Local\Temp\ipykernel_18644\63180315.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(best_model_path)
# Test ROC Curve plot saved at: scratch_test_augmentless/saved_models\test_roc_curve.png

# %% [markdown]
# ## Plotting

# %%
plt.figure(figsize=(15, 12))


plt.subplot(3, 1, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train vs Validation Loss")
plt.legend()
plt.grid(True)


plt.text(num_epochs - 1, val_losses[-1], f"Final Val Loss: {val_losses[-1]:.4f}", 
         fontsize=10, color='orange')


plt.subplot(3, 1, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy', marker='o', color='blue')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Validation Accuracy', marker='o', color='orange')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train vs Validation Accuracy")
plt.legend()
plt.grid(True)



test_accuracy = sum([y_true[i] == y_pred[i] for i in range(len(y_true))]) / len(y_true)
print(f"Test Accuracy: {test_accuracy:.4f}")
plt.text(num_epochs - 1, val_accuracies[-1], f"Test Accuracy: {test_accuracy:.4f}", 
         fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.5))


plt.subplot(3, 1, 3)
plt.plot(range(1, num_epochs + 1), val_aucs, label="Validation AUC", marker='o', color='green')
plt.plot(range(1, num_epochs + 1), val_paucs, label="Validation pAUC (FPR ≤ 0.1)", marker='o', color='purple')
plt.xlabel("Epochs")
plt.ylabel("AUC")
plt.title("Validation AUC and pAUC")
plt.legend()
plt.grid(True)


plt.text(num_epochs - 1, val_aucs[-1], f"Test AUC: {roc_auc:.4f}", 
         fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.5))
plt.text(num_epochs - 1, val_paucs[-1], f"Test pAUC: {partial_auc:.4f}", 
         fontsize=10, color='red', bbox=dict(facecolor='white', alpha=0.5))


combined_plot_path = os.path.join(model_dir, "combined_metrics.png")
plt.tight_layout()
plt.savefig(combined_plot_path, bbox_inches="tight")
plt.show()

print(f"Combined metrics plot saved at: {combined_plot_path}")
# Out:
# Test Accuracy: 0.7949
# Combined metrics plot saved at: scratch_test_augmentless/saved_models\combined_metrics.png

# %%
params_file_path = os.path.join(model_dir, "model_params.txt")
with open(params_file_path, "w") as f:
    f.write("Model Architecture:\n")
    f.write(str(fine_tuned_model) + "\n\n")  
    
    f.write("Hyperparameters:\n")
    f.write(f"Batch Size: {batch_size}\n")
    f.write(f"Learning Rate: {learning_rate}\n")
    f.write(f"Number of Epochs: {num_epochs}\n")
    f.write(f"Optimizer: Adam\n")
    f.write(f"Loss Function: CrossEntropyLoss\n")
    
print(f"Model parameters and architecture saved to {params_file_path}")
# Out:
# Model parameters and architecture saved to scratch_test_augmentless/saved_models\model_params.txt
